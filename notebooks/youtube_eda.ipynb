# %%
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt

# %%
US_df = pd.read_csv('/Volumes/64gig data_sets/youtube_data/USvideos.csv')
USjson_df = pd.read_json('/Volumes/64gig data_sets/youtube_data/US_category_id.json')

# %%
US_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
US_df.title.nunique()
# Out:
# 6455

# %%
US_df.title.value_counts()
# Out:
# WE MADE OUR MOM CRY...HER DREAM CAME TRUE!                       30
# YoungBoy Never Broke Again Goes Sneaker Shopping With Complex    29
# Rooster Teeth Animated Adventures - Millie So Serious            29
# Why I'm So Scared (being myself and crying too much)             29
# Sam Smith - Pray (Official Video) ft. Logic                      29
#                                                                  ..
# Apple iPhone X Review: The Best Yet!                              1
# Greenland is melting                                              1
# Lisa Kudrow is Handling Her Son Going to College Very Well        1
# Owen Wilson on Meeting Julia Roberts, and Tandem Biking           1
# Rosé Facial in New York City                                      1
# Name: title, Length: 6455, dtype: int64

# %%
US_df['title'].value_counts().value_counts(lambda x:x>1)
# Out:
# 1     0.119442
# 6     0.117738
# 7     0.108133
# 5     0.107359
# 3     0.092796
# 4     0.087839
# 2     0.086290
# 8     0.055616
# 9     0.038575
# 11    0.027885
# 13    0.027730
# 12    0.025871
# 10    0.024167
# 14    0.021998
# 15    0.014407
# 16    0.007901
# 18    0.006197
# 17    0.006042
# 19    0.003873
# 21    0.003563
# 20    0.003253
# 22    0.002634
# 25    0.002479
# 23    0.002324
# 27    0.001549
# 28    0.001394
# 24    0.001239
# 29    0.001084
# 26    0.000465
# 30    0.000155
# Name: title, dtype: float64

# %%
US_df['title'].value_counts().loc[lambda x : x>1].hist();

# %%
US_df.category_id.value_counts()

# 2 - Autos & Vehicles
# 1 -  Film & Animation
# 10 - Music
# 15 - Pets & Animals
# 17 - Sports
# 18 - Short Movies
# 19 - Travel & Events
# 20 - Gaming
# 21 - Videoblogging
# 22 - People & Blogs
# 23 - Comedy
# 24 - Entertainment
# 25 - News & Politics
# 26 - Howto & Style
# 27 - Education
# 28 - Science & Technology
# 29 - Nonprofits & Activism
# 30 - Movies
# 31 - Anime/Animation
# 32 - Action/Adventure
# 33 - Classics
# 34 - Comedy
# 35 - Documentary
# 36 - Drama
# 37 - Family
# 38 - Foreign
# 39 - Horror
# 40 - Sci-Fi/Fantasy
# 41 - Thriller
# 42 - Shorts
# 43 - Shows
# 44 - Trailers


# From  youtube upload page
#     2 - Cars & Vehicles
#     23 - Comedy
#     27 - Education
#     24 - Entertainment
#     1 - Film & Animation
#     20 - Gaming
#     26 - How-to & Style
#     10 - Music
#     25 - News & Politics
#     29 - Non-profits & Activism
#     22 - People & Blogs
#     15 - Pets & Animals
#     28 - Science & Technology
#     17 - Sport
#     19 - Travel & Events
# Out:
# 24    9964
# 10    6472
# 26    4146
# 23    3457
# 22    3210
# 25    2487
# 28    2401
# 1     2345
# 17    2174
# 27    1656
# 15     920
# 20     817
# 19     402
# 2      384
# 29      57
# 43      57
# Name: category_id, dtype: int64

# %%
US_df.tail()
# Out:
#           video_id trending_date  \
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# ...

# %%
US_df.shape
# Out:
# (40949, 16)

# %%
US_df.nunique()
# Out:
# video_id                   6351
# trending_date               205
# title                      6455
# channel_title              2207
# category_id                  16
# publish_time               6269
# tags                       6055
# views                     40478
# likes                     29850
# dislikes                   8516
# comment_count             13773
# thumbnail_link             6352
# comments_disabled             2
# ratings_disabled              2
# video_error_or_removed        2
# description                6901
# dtype: int64

# %%
US_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
US_df.publish_time
# Out:
# 0        2017-11-13T17:13:01.000Z
# 1        2017-11-13T07:30:00.000Z
# 2        2017-11-12T19:05:24.000Z
# 3        2017-11-13T11:00:04.000Z
# 4        2017-11-12T18:01:41.000Z
#                    ...
# 40944    2018-05-18T13:00:04.000Z
# 40945    2018-05-18T01:00:06.000Z
# 40946    2018-05-18T17:34:22.000Z
# 40947    2018-05-17T17:00:04.000Z
# 40948    2018-05-17T17:09:38.000Z
# Name: publish_time, Length: 40949, dtype: object

# %%
US_df.views.describe()
# Out:
# count    4.094900e+04
# mean     2.360785e+06
# std      7.394114e+06
# min      5.490000e+02
# 25%      2.423290e+05
# 50%      6.818610e+05
# 75%      1.823157e+06
# max      2.252119e+08
# Name: views, dtype: float64

# %%
US_df.groupby('category_id')['views'].value_counts(bins=3)
# Out:
# category_id
# 1            (-53919.969999999994, 18288599.333]    2275
#              (18288599.333, 36576255.667]             59
#              (36576255.667, 54863912.0]               11
# 2            (-22381.238, 8416605.667]               367
#              (8416605.667, 16830351.333]              13
#              (16830351.333, 25244097.0]                4
# 10           (-223619.33299999998, 75071701.667]    6411
#              (75071701.667, 150141812.333]            47
#              (150141812.333, 225211923.0]             14
# 15           (-2791.065, 2064747.667]                831
#              (2064747.667, 4126102.333]               65
#              (4126102.333, 6187457.0]                 24
# 17           (-28432.142, 9697371.667]              2026
#              (9697371.667, 19394085.333]             127
#              (19394085.333, 29090799.0]               21
# 19           (-23142.633, 7977999.667]               397
# ...

# %%
US_df.groupby('category_id')['likes'].value_counts(bins=3)
# Out:
# category_id
# 1            (-922.356, 307451.667]              2204
#              (307451.667, 614903.333]             121
#              (614903.333, 922355.0]                20
# 2            (-97.031, 32343.333]                 358
#              (32343.333, 64686.667]                22
#              (64686.667, 97030.0]                   4
# 10           (-5613.828, 1871275.667]            6373
#              (1871275.667, 3742551.333]            68
#              (3742551.333, 5613827.0]              31
# 15           (-172.238, 59418.333]                859
#              (59418.333, 118830.667]               50
#              (118830.667, 178243.0]                11
# 17           (-1121.218, 373739.0]               2070
#              (373739.0, 747478.0]                  86
#              (747478.0, 1121217.0]                 18
# 19           (-39.445, 14151.0]                   255
#              (14151.0, 28299.0]                   106
# ...

# %%
US_df.groupby('category_id')['views'].value_counts()
# Out:
# category_id  views
# 1            60262       2
#              404162      2
#              520049      2
#              15960127    2
#              943         1
#                         ..
# 43           1358075     1
#              1368638     1
#              1400041     1
#              1430566     1
#              1445949     1
# Name: views, Length: 40844, dtype: int64

# %%
US_df.groupby('category_id')['views'].value_counts(bins= 1)
# Out:
# category_id
# 1            (-53919.969999999994, 54863912.0]     2345
# 2            (-22381.238, 25244097.0]               384
# 10           (-223619.33299999998, 225211923.0]    6472
# 15           (-2791.065, 6187457.0]                 920
# 17           (-28432.142, 29090799.0]              2174
# 19           (-23142.633, 23932421.0]               402
# 20           (-15697.206, 16935442.0]               817
# 22           (-55227.07399999999, 56111957.0]      3210
# 23           (-27369.29, 29178096.0]               3457
# 24           (-148577.33, 149376127.0]             9964
# 25           (-9727.81, 10277358.0]                2487
# 26           (-53047.814999999995, 54155921.0]     4146
# 27           (-6575.6630000000005, 7349435.0]      1656
# 28           (-41815.475999999995, 42799458.0]     2401
# 29           (-22829.019, 24286474.0]                57
# 43           (35199.65900000001, 1445949.0]          57
# Name: views, dtype: int64

# %%
 US_df.groupby(by=["category_id"], dropna=False).sum()
# Out:
#                    views       likes  dislikes  comment_count  \
# category_id
# 1             7284156721   165997476   6075148       17887060
# 2              520690717     4245656    243010         784447
# 10           40132892190  1416838584  51179008      125296396
# 15             764651989    19370702    527379        2660705
# 17            4404456673    98621211   5133551       11192155
# 19             343557084     4836246    340427         911511
# 20            2141218625    69038284   9184466       14740713
# 22            4917191726   186615999  10187901       24778032
# 23            5117426208   216346746   7230391       22545582
# 24           20604388195   530516491  42987663       73566498
# 25            1473765704    18151033   4180049        6039433
# 26            4078545064   162880075   5473899       23149550
# 27            1180629990    49257772   1351972        5442242
# 28            3487756816    82532638   4548402       11989926
# ...

# %%
catagory_df = US_df.groupby(by=["category_id"], dropna=False).sum()

# %%
catagory_df.head()
# Out:
#                    views       likes  dislikes  comment_count  \
# category_id
# 1             7284156721   165997476   6075148       17887060
# 2              520690717     4245656    243010         784447
# 10           40132892190  1416838584  51179008      125296396
# 15             764651989    19370702    527379        2660705
# 17            4404456673    98621211   5133551       11192155
#
#              comments_disabled  ratings_disabled  video_error_or_removed
# category_id
# 1                           28                14                      13
# 2                            5                10                       0
# 10                           9                24                       0
# 15                           4                 0                       0
# 17                          28                17                       2

# %%
catagory_df
# Out:
#                    views       likes  dislikes  comment_count  \
# category_id
# 1             7284156721   165997476   6075148       17887060
# 2              520690717     4245656    243010         784447
# 10           40132892190  1416838584  51179008      125296396
# 15             764651989    19370702    527379        2660705
# 17            4404456673    98621211   5133551       11192155
# 19             343557084     4836246    340427         911511
# 20            2141218625    69038284   9184466       14740713
# 22            4917191726   186615999  10187901       24778032
# 23            5117426208   216346746   7230391       22545582
# 24           20604388195   530516491  42987663       73566498
# 25            1473765704    18151033   4180049        6039433
# 26            4078545064   162880075   5473899       23149550
# 27            1180629990    49257772   1351972        5442242
# 28            3487756816    82532638   4548402       11989926
# ...

# %%
catagory_df.category_id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-2ccaf2aaf999> in <module>
# ----> 1 catagory_df.category_id
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'category_id'

# %%
catagory_df['views'].plot(kind="bar");

# %%
catagory_df.sort_values('views', ascending=False)[['views']].plot.bar()

# plt.xlabel('state')
# ax = catagory_df.sort_values('views', ascending=False)[['views']].plot.bar()

# fig, ax  =  plt.subplots(figsize=(8,8))
# ax.bar
# ax.set_xticks(x)
# ax.set_xticklabels(record_counts['genre']);
# Out:
# <AxesSubplot:xlabel='category_id'>

# %%
US_df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
catagory_df.sort_values('likes', ascending=False)[['likes']].plot.bar()
# Out:
# <AxesSubplot:xlabel='category_id'>

# %%
catagory_df.sort_values('comment_count', ascending=False)[['comment_count']].plot.bar()
# Out:
# <AxesSubplot:xlabel='category_id'>

# %%
US_df.channel_title.nunique()
# Out:
# 2207

# %%
US_df.channel_title.value_counts()
# Out:
# ESPN                                      203
# The Tonight Show Starring Jimmy Fallon    197
# TheEllenShow                              193
# Netflix                                   193
# Vox                                       193
#                                          ...
# Chad Kroeger                                1
# chris lee                                   1
# bitluni's lab                               1
# Humble Design                               1
# BeyondSlowMotion                            1
# Name: channel_title, Length: 2207, dtype: int64

# %%
US_df['channel_title'].value_counts().loc[lambda x : x>1].hist();

# %%
US_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
US_df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
USjson_df.etag.nunique()
# Out:
# 1

# %%
USjson_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   kind    32 non-null     object
#  1   etag    32 non-null     object
#  2   items   32 non-null     object
# dtypes: object(3)
# memory usage: 896.0+ bytes

# %%
import json 
import pandas as pd 
from pandas.io.json import json_normalize 
  
# with open('https://github.com/a9k00r/python-test/blob/master/raw_nyc_phil.json') as f:
#     d = json.load(f)
  
# lets put the data into a pandas df
# clicking on raw_nyc_phil.json under "Input Files"
# tells us parent node is 'programs'
items_json_df = json_normalize(USjson_df['items'])
items_json_df.head(3)
# Out:
# /Users/cp/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # This is added back by InteractiveShellApp.init_path()
#                     kind                                               etag  \
# 0  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
# 1  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
# 2  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
#
#    id         snippet.channelId     snippet.title  snippet.assignable
# 0   1  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation                True
# 1   2  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles                True
# 2  10  UCBR8-60-B28hp2BmDPdntcQ             Music                True

# %%
items_json_df
# Out:
#                      kind                                               etag  \
# 0   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
# 1   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
# 2   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
# 3   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...
# 4   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...
# 5   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/FJwVpGCVZ1yiJrqZb...
# 6   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/M-3iD9dwK7YJCafRf...
# 7   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/WmA0qYEfjWsAoyJFS...
# 8   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/EapFaGYG7K0StIXVf...
# 9   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# 10  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/G9LHzQmx44rX2S5ya...
# ...

# %%
USjson_df.items.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-2a26eeff2c7c> in <module>
# ----> 1 USjson_df.items.shape
#
# AttributeError: 'function' object has no attribute 'shape'

# %%
items_json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   kind                32 non-null     object
#  1   etag                32 non-null     object
#  2   id                  32 non-null     object
#  3   snippet.channelId   32 non-null     object
#  4   snippet.title       32 non-null     object
#  5   snippet.assignable  32 non-null     bool
# dtypes: bool(1), object(5)
# memory usage: 1.4+ KB

# %%
USjson_df['items'].shape
# Out:
# (32,)

# %%
USjson_df['items'].iloc[1]
# Out:
# {'kind': 'youtube#videoCategory',
#  'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45ZTFR3a3NyTA"',
#  'id': '2',
#  'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'title': 'Autos & Vehicles',
#   'assignable': True}}

# %%
US_df.iloc[1]
# Out:
# video_id                                                        1ZAPwfrtAFY
# trending_date                                                      17.14.11
# title                     The Trump Presidency: Last Week Tonight with J...
# channel_title                                               LastWeekTonight
# category_id                                                              24
# publish_time                                       2017-11-13T07:30:00.000Z
# tags                      last week tonight trump presidency|"last week ...
# views                                                               2418783
# likes                                                                 97185
# dislikes                                                               6146
# comment_count                                                         12703
# thumbnail_link               https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# ...

# %%
items_json_df.head()
# Out:
#                     kind                                               etag  \
# 0  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
# 1  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
# 2  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
# 3  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...
# 4  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...
#
#    id         snippet.channelId     snippet.title  snippet.assignable
# 0   1  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation                True
# 1   2  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles                True
# 2  10  UCBR8-60-B28hp2BmDPdntcQ             Music                True
# 3  15  UCBR8-60-B28hp2BmDPdntcQ    Pets & Animals                True
# 4  17  UCBR8-60-B28hp2BmDPdntcQ            Sports                True

# %%
items_json_df
# Out:
#                      kind                                               etag  \
# 0   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
# 1   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
# 2   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
# 3   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...
# 4   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...
# 5   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/FJwVpGCVZ1yiJrqZb...
# 6   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/M-3iD9dwK7YJCafRf...
# 7   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/WmA0qYEfjWsAoyJFS...
# 8   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/EapFaGYG7K0StIXVf...
# 9   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# 10  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/G9LHzQmx44rX2S5ya...
# ...

# %%
items_json_df.id.nunique()
# Out:
# 32

# %%
items_json_df['snippet.title'].nunique()
# Out:
# 31

# %%
items_json_df['id'].nunique()
# Out:
# 32

# %%
items_json_df.shape
# Out:
# (32, 6)

# %%
items_json_df['snippet.title'].value_counts()
# Out:
# Comedy                   2
# Autos & Vehicles         1
# Howto & Style            1
# Education                1
# Family                   1
# Short Movies             1
# Shorts                   1
# Thriller                 1
# Sci-Fi/Fantasy           1
# Documentary              1
# Classics                 1
# Science & Technology     1
# Horror                   1
# Entertainment            1
# Movies                   1
# News & Politics          1
# Sports                   1
# Action/Adventure         1
# Travel & Events          1
# People & Blogs           1
# Gaming                   1
# Pets & Animals           1
# Shows                    1
# Music                    1
# Film & Animation         1
# Drama                    1
# Nonprofits & Activism    1
# Anime/Animation          1
# Foreign                  1
# Videoblogging            1
# Trailers                 1
# Name: snippet.title, dtype: int64

# %%
items_json_df.columns
# Out:
# Index(['kind', 'etag', 'id', 'snippet.channelId', 'snippet.title',
#        'snippet.assignable'],
#       dtype='object')

# %%
items_json_df['kind'].value_counts()
# Out:
# youtube#videoCategory    32
# Name: kind, dtype: int64

# %%
items_json_df.kind.iloc[1]
# Out:
# 'youtube#videoCategory'

# %%
items_json_df['snippet.channelId'].value_counts()
# Out:
# UCBR8-60-B28hp2BmDPdntcQ    32
# Name: snippet.channelId, dtype: int64

# %%
US_df.channel_title.value_counts()
# Out:
# ESPN                                      203
# The Tonight Show Starring Jimmy Fallon    197
# TheEllenShow                              193
# Netflix                                   193
# Vox                                       193
#                                          ...
# Chad Kroeger                                1
# chris lee                                   1
# bitluni's lab                               1
# Humble Design                               1
# BeyondSlowMotion                            1
# Name: channel_title, Length: 2207, dtype: int64

# %%
# channel_df = US_df.channel_title
# channel_df.sort_values('comment_count', ascending=False)[['comment_count']].plot.bar()
US_df['channel_title'].value_counts().loc[lambda x : x>100].hist();

# %%
pd.set_option('display.max_rows', 10)
# pd.set_option('display.max_rows', 1)
US_df['channel_title'].value_counts().loc[lambda x : x>100]
# Out:
# ESPN                                      203
# The Tonight Show Starring Jimmy Fallon    197
# TheEllenShow                              193
# Netflix                                   193
# Vox                                       193
#                                          ...
# TODAY                                     102
# The Film Theorists                        102
# Tati                                      102
# Hannah Stocking                           102
# CinemaSins                                101
# Name: channel_title, Length: 69, dtype: int64

# %%
US_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
US_df.description.describe()
# Out:
# count                                                 40379
# unique                                                 6901
# top       ► Listen LIVE: http://power1051fm.com/\n► Face...
# freq                                                     58
# Name: description, dtype: object

# %%
catagory_dict={
2 : 'Autos & Vehicles'
,1 :  'Film & Animation'
,10 : 'Music'
,15 : 'Pets & Animals'
,17 : 'Sports'
,18 : 'Short Movies'
,19 : 'Travel & Events'
,20 : 'Gaming'
,21 : 'Videoblogging'
,22 : 'People & Blogs'
,23 : 'Comedy'
,24 : 'Entertainment'
,25 : 'News & Politics'
,26 : 'Howto & Style'
,27 : 'Education'
,28 : 'Science & Technology'
,29 : 'Nonprofits & Activism'
,30 : 'Movies'
,31 : 'Anime/Animation'
,32 : 'Action/Adventure'
,33 : 'Classics'
,34 : 'Comedy'
,35 : 'Documentary'
,36 : 'Drama'
,37 : 'Family'
,38 : 'Foreign'
,39 : 'Horror'
,40 : 'Sci-Fi/Fantasy'
,41 : 'Thriller'
,42 : 'Shorts'
,43 : 'Shows'
,44 : 'Trailers'}

# %%
catagory_df['catagory_new'] = catagory_df.index.to_series().map(catagory_dict)
# df['two'] = df.index.to_series().map(map_dict)
# df['two'] = df.index.to_series().map(map_dict)

# %%
catagory_df
# Out:
#                    views       likes  dislikes  comment_count  \
# category_id
# 1             7284156721   165997476   6075148       17887060
# 2              520690717     4245656    243010         784447
# 10           40132892190  1416838584  51179008      125296396
# 15             764651989    19370702    527379        2660705
# 17            4404456673    98621211   5133551       11192155
# ...                  ...         ...       ...            ...
# 26            4078545064   162880075   5473899       23149550
# 27            1180629990    49257772   1351972        5442242
# 28            3487756816    82532638   4548402       11989926
# 29             168941392    14815646   3310381        4808797
# 43              51501058     1082639     24508          95117
#
#              comments_disabled  ratings_disabled  video_error_or_removed  \
# category_id
# 1                           28                14                      13
# ...

# %%
US_df['catagory_new']= US_df.category_id.map(catagory_dict)

# %%
US_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
US_df.trending_date.value_counts()
# Out:
# 18.07.04    200
# 17.19.11    200
# 18.09.03    200
# 18.06.04    200
# 17.18.11    200
#            ...
# 18.01.02    197
# 18.31.01    197
# 18.04.02    196
# 18.02.02    196
# 18.03.02    196
# Name: trending_date, Length: 205, dtype: int64

# %%
# US_df['trending_date'].to_datetime

# pd.to_datetime('13000101', format='%Y%m%d', errors='ignore')

# %%
# US_df['trending_date2'] = pd.to_datetime(US_df['trending_date'],format = '%Y.%d.m%')

# %%
def fix_date(str1):
#     print(str1)
    lst1 = str1.split('.')
#     print(lst1)
    lst1.reverse()
#     print(lst1)
    results = "-".join(lst1)
    return results

# %%
print(fix_date('18.01.02'))
# Out:
# 02-01-18

# %%
deleteme = '18.01.02'.split('.')

# %%
deleteme.reverse()

# %%
US_df['trending_date2'] = US_df.trending_date.apply(fix_date)

# %%
US_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
US_df['trending_date2'] = pd.to_datetime(US_df['trending_date2'],infer_datetime_format=True)

# %%
US_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
US_df['publish_time2'] = pd.to_datetime(US_df['publish_time'],infer_datetime_format=True)

# %%
US_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
rating_disabled_df = US_df[US_df.ratings_disabled == True]
rating_disabled_df_catagory_df = rating_disabled_df.groupby(by=["category_id"], dropna=False).sum()

# %%
rating_disabled_df_catagory_df.sort_values('views', ascending=False)[['views']].plot.bar()
# Out:
# <AxesSubplot:xlabel='category_id'>

# %%
comment_disabled_df = US_df[US_df.comments_disabled == True]
comment_disabled_df_catagory_df = comment_disabled_df.groupby(by=["category_id"], dropna=False).sum()
comment_disabled_df_catagory_df.sort_values('views', ascending=False)[['views']].plot.bar()
# Out:
# <AxesSubplot:xlabel='category_id'>

# %%
US_df.tags.iloc[1]
# Out:
# 'last week tonight trump presidency|"last week tonight donald trump"|"john oliver trump"|"donald trump"'

# %%
US_df.tags.iloc[2]
# Out:
# 'racist superman|"rudy"|"mancuso"|"king"|"bach"|"racist"|"superman"|"love"|"rudy mancuso poo bear black white official music video"|"iphone x by pineapple"|"lelepons"|"hannahstocking"|"rudymancuso"|"inanna"|"anwar"|"sarkis"|"shots"|"shotsstudios"|"alesso"|"anitta"|"brazil"|"Getting My Driver\'s License | Lele Pons"'

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer (max_features = 5000, stop_words = 'english', strip_accents='unicode')

# %%
text = US_df.tags

# %%
X = vectorizer.fit_transform(text)

# %%
feature_names = vectorizer.get_feature_names()
feature_names

vocabulary = np.array(feature_names)

# %%
len(feature_names)
# Out:
# 5000

# %%
from sklearn.decomposition import NMF

# %%
k =10
nmf = NMF(n_components=k, init='random', random_state=0)
W = nmf.fit_transform(X)
H = nmf.components_

# %%
W
# Out:
# array([[2.01199117e-03, 3.63483535e-04, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.15975949e-04],
#        [6.51496916e-03, 1.00368702e-01, 0.00000000e+00, ...,
#         7.05580983e-04, 6.00590633e-03, 0.00000000e+00],
#        [2.12648543e-01, 0.00000000e+00, 8.78982865e-02, ...,
#         2.67523866e-02, 7.97297753e-03, 0.00000000e+00],
#        ...,
#        [3.53196981e-02, 0.00000000e+00, 1.99742271e-03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.58947123e-02, 9.04707031e-03, ...,
#         1.40128004e-01, 3.24659718e-02, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         3.23767988e-02, 7.84791408e-03, 0.00000000e+00]])

# %%
H.shape
# Out:
# (10, 5000)

# %%
indices = np.argsort(H[0])[::-1]
indices
# Out:
# array([4689, 3053, 3120, ..., 2536, 2531,    0])

# %%
k = 10
nmf = NMF(n_components=k, init='random', random_state=0)
W = nmf.fit_transform(X)
H = nmf.components_

# %%
def hand_label_topics(H, vocabulary):
    '''
    Print the most influential words of each latent topic, and prompt the user
    to label each topic. The user should use their humanness to figure out what
    each latent topic is capturing.
    '''
    hand_labels = []
    for i, row in enumerate(H):
        top_five = np.argsort(row)[::-1][:20]
        print('topic', i)
        print('-->', ' '.join(vocabulary[top_five]))
#         label = input('please label this topic: ')
#         hand_labels.append(label)
        print()
    return hand_labels
hand_label_topics(H, vocabulary)
# Out:
# topic 0
# --> video music new official song diplo live daddy voice lsd maluma yankee pop love 2018 audio natasha natti 2017 charlie
#
# topic 1
# --> news celebrity nbc 2018 kardashian live world today trump entertainment breaking kim time graham interview voice politics tv season volcano
#
# topic 2
# --> iphone s9 galaxy apple samsung 2018 vs review plus unboxing 11 leaks ios new best logo ipad crash test unbox
#
# topic 3
# --> youtube smith channel alex clark life itsalexclark noggin vlogs vlog comedy videos school cake animated animation education react lilly anthony
#
# topic 4
# --> dude perfect bottle flip family trick water spinners basketball nerf friendly fortnite shots world challenge bowling record battle football anvil
#
# topic 5
# --> makeup tutorial beauty face challenge james charles routine kardashian cosmetics kim everyday review products transformation sephora drugstore using glam tutorials
#
# topic 6
# ...

# %%
from time import time
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
# from sklearn.datasets import fetch_20newsgroups

n_samples = 2000
n_features = 1000
n_components = 10
n_top_words = 20


def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 30})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=20)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()
    

tf_feature_names = vectorizer.get_feature_names()
plot_top_words(nmf, tf_feature_names, n_top_words, 'Youtube topics')
# Out:
# /Users/cp/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 2337 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/cp/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 2348 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/cp/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 2354 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/cp/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 2358 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/cp/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# US_df.description = US_df.description.dropna()

US_df = US_df[US_df['description'].notna()]

# %%
US_df.description.isnull().sum()

# df['your column name'].isnull().sum()
# Out:
# 0

# %%
text2 = US_df.description
X2 = vectorizer.fit_transform(text2)
feature_names2 = vectorizer.get_feature_names()
# feature_names2

vocabulary2 = np.array(feature_names2)
k =10
nmf = NMF(n_components=k, init='random', random_state=0)
W = nmf.fit_transform(X)
H = nmf.components_
indices = np.argsort(H[0])[::-1]

k = 10
nmf = NMF(n_components=k, init='random', random_state=0)
W = nmf.fit_transform(X)
H = nmf.components_

# %%
def hand_label_topics(H, vocabulary):
    '''
    Print the most influential words of each latent topic, and prompt the user
    to label each topic. The user should use their humanness to figure out what
    each latent topic is capturing.
    '''
    hand_labels = []
    for i, row in enumerate(H):
        top_five = np.argsort(row)[::-1][:20]
        print('topic', i)
        print('-->', ' '.join(vocabulary[top_five]))
#         label = input('please label this topic: ')
#         hand_labels.append(label)
        print()
    return hand_labels
hand_label_topics(H, vocabulary2)
# Out:
# topic 0
# --> updated njames nmusical nsenior singer documentaries microphone danny vanity monday mythical worldwide pause modern 16f1jec apply nlike nliza 16 cheap
#
# topic 1
# --> nmy celebrities nlos 16f1jec lillysingh microphone williamosman thescranline traditional eyeshadows boyfriend london theatres higher kids vanity patgraziosi traveler royalty vat19
#
# topic 2
# --> kind reserved grinch amazing review 16f1jec veins ptx parodies truck 0bsajo marvel kimmelmt10 nmusical bdgsbmbh minutes kimmeltw creations tanner troyesivan
#
# topic 3
# --> ws shirts characters 9c club melissa kobe nour valuables va complicated updates role buzzfeedvideohttps african age era pranks merch alesso
#
# topic 4
# --> eliminations ok blurred games filter tori vocalists smith awards nmike gomez girlfriend score williamosman change board prevent baby ghost alive
#
# topic 5
# ...

# %%
from time import time
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
# from sklearn.datasets import fetch_20newsgroups

n_samples = 2000
n_features = 1000
n_components = 10
n_top_words = 20


def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 30})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=20)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()
    

tf_feature_names = vectorizer.get_feature_names()
plot_top_words(nmf, tf_feature_names, n_top_words, 'Youtube topics')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
v = TfidfVectorizer()
x = v.fit_transform(text)

# %%
text
# Out:
# 0                                          SHANtell martin
# 1        last week tonight trump presidency|"last week ...
# 2        racist superman|"rudy"|"mancuso"|"king"|"bach"...
# 3        rhett and link|"gmm"|"good mythical morning"|"...
# 4        ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...
#                                ...
# 40944    aarons animals|"aarons"|"animals"|"cat"|"cats"...
# 40945                                               [none]
# 40946    I gave safiya nygaard a perfect hair makeover ...
# 40947    Black Panther|"HISHE"|"Marvel"|"Infinity War"|...
# 40948        call of duty|"cod"|"activision"|"Black Ops 4"
# Name: tags, Length: 40949, dtype: object

# %%
feature_names2 = v.get_feature_names()
# feature_names2

vocabulary2 = np.array(feature_names2)
k =10
nmf = NMF(n_components=k, init='random', random_state=0)
W = nmf.fit_transform(x)
H = nmf.components_
indices = np.argsort(H[0])[::-1]

k = 10
nmf = NMF(n_components=k, init='random', random_state=0)
W = nmf.fit_transform(x)
H = nmf.components_

# %%
def hand_label_topics(H, vocabulary2):
    '''
    Print the most influential words of each latent topic, and prompt the user
    to label each topic. The user should use their humanness to figure out what
    each latent topic is capturing.
    '''
    hand_labels = []
    for i, row in enumerate(H):
        top_five = np.argsort(row)[::-1][:20]
        print('topic', i)
        print('-->', ' '.join(vocabulary[top_five]))
#         label = input('please label this topic: ')
#         hand_labels.append(label)
        print()
    return hand_labels
hand_label_topics(H, vocabulary2)
# Out:
# topic 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-e144eb84db58> in <module>
#      14         print()
#      15     return hand_labels
# ---> 16 hand_label_topics(H, vocabulary2)
#
# <ipython-input-104-e144eb84db58> in hand_label_topics(H, vocabulary2)
#       9         top_five = np.argsort(row)[::-1][:20]
#      10         print('topic', i)
# ---> 11         print('-->', ' '.join(vocabulary[top_five]))
#      12 #         label = input('please label this topic: ')
#      13 #         hand_labels.append(label)
#
# IndexError: index 20423 is out of bounds for axis 0 with size 5000

# %%
from time import time
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
# from sklearn.datasets import fetch_20newsgroups

n_samples = 2000
n_features = 1000
n_components = 10
n_top_words = 20


def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 30})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=20)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()
    

tf_feature_names = vectorizer.get_feature_names()
plot_top_words(nmf, tf_feature_names, n_top_words, 'Youtube topics')

# %%
len(vocabulary)

# %%
len(feature_names2)

# %%
catagory_df
# Out:
#                    views       likes  dislikes  comment_count  \
# category_id
# 1             7284156721   165997476   6075148       17887060
# 2              520690717     4245656    243010         784447
# 10           40132892190  1416838584  51179008      125296396
# 15             764651989    19370702    527379        2660705
# 17            4404456673    98621211   5133551       11192155
# ...                  ...         ...       ...            ...
# 26            4078545064   162880075   5473899       23149550
# 27            1180629990    49257772   1351972        5442242
# 28            3487756816    82532638   4548402       11989926
# 29             168941392    14815646   3310381        4808797
# 43              51501058     1082639     24508          95117
#
#              comments_disabled  ratings_disabled  video_error_or_removed  \
# category_id
# 1                           28                14                      13
# ...

# %%
rating_disabled_df_catagory_df
# Out:
#                  views  likes  dislikes  comment_count  comments_disabled  \
# category_id
# 1               588302      0         0              7                 11
# 2              4431750      0         0           7893                  0
# 10            70623745      0         0          37685                  8
# 17             4037044      0         0            155                 13
# 22           474818509      0         0          13856                 23
# ...                ...    ...       ...            ...                ...
# 25               22690      0         0              0                  1
# 26             9835545      0         0              0                 11
# 27              183072      0         0            121                  1
# 28            10239805      0         0             17                 15
# 29                7427      0         0              0                  4
#
#              ratings_disabled  video_error_or_removed
# ...

# %%
comment_disabled_df_catagory_df
# Out:
#                  views    likes  dislikes  comment_count  comments_disabled  \
# category_id
# 1             23522292    88949     89778              0                 28
# 2                61875      182        70              0                  5
# 10            24806308    42556      2791              0                  9
# 15              718213     6185       540              0                  4
# 17            41869795   936733     24577              0                 28
# ...                ...      ...       ...            ...                ...
# 25           223305141  1371691    166691              0                174
# 26             9835545        0         0              0                 11
# 27               88620      986        68              0                  8
# 28           276254827  2912021    657885              0                 90
# 29                7427        0         0              0                  4
#
# ...
